# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt
import statistics
from scipy import stats
from collections import Counter

# %%
df = pd.read_csv("D:/Data Analysis/good_reads_final.csv")

# %%
fig = plt.figure(figsize = (10,15))
ax = fig.gca()
df.hist(ax=ax,bins=10)
#data['score'].hist(bins=10)
# Out:
# C:\Users\mukes\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3267: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002BC6317AEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BC62014208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BC6203C780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002BC62062CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BC6208A6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BC620B1C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002BC620E31D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BC62109780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BC621097B8>]],
#       dtype=object)

# %%
df=df.sample(n=50)
df.plot.box()

# %%
df.iloc[:20].plot.bar()
plt.show()

# %%
freq = {} 
for item in df.genre_1: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1
key=[x for x in freq.keys()]
key
value=[freq[x] for x in freq.keys()]
value
# Out:
# [3, 7, 2, 4, 5, 7, 6, 1, 3, 1, 2, 1, 1, 2, 1, 2, 1, 1]

# %%
temp1 = df['genre_1'].value_counts(ascending=True)
temp2 = dict(Counter(df['genre_1']))
count_row = df.shape[0]
for i in temp2:
    temp2[i]=round((temp2[i]/count_row)*100,2)
print ('Frequency Table for Genre:') 
print (temp1)

print ('\nPercentage of each genre:')
print (temp2)
# Out:
# Frequency Table for Genre:
# Amish                1
# Realistic Fiction    1
# Humor                1
# Paranormal           1
# New Adult            1
# Mystery              1
# Poetry               1
# Nonfiction           2
# Horror               2
# Romance              2
# Science              2
# Historical           3
# Childrens            3
# Fiction              4
# Classics             5
# Young Adult          6
# Science Fiction      7
# Fantasy              7
# Name: genre_1, dtype: int64
#
# Percentage of each genre:
# {'Childrens': 6.0, 'Science Fiction': 14.0, 'Nonfiction': 4.0, 'Fiction': 8.0, 'Classics': 10.0, 'Fantasy': 14.0, 'Young Adult': 12.0, 'Realistic Fiction': 2.0, 'Historical': 6.0, 'Poetry': 2.0, 'Horror': 4.0, 'Mystery': 2.0, 'Humor': 2.0, 'Science': 4.0, 'New Adult': 2.0, 'Romance': 4.0, 'Paranormal': 2.0, 'Amish': 2.0}

# %%
lists = sorted(temp2.items())
fig = plt.figure(figsize=(30,10))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Genres')
ax1.set_ylabel('Genres percentage')
ax1.set_title("Probability of each genre")
x, y = zip(*lists)
plt.bar(x, y)
plt.show()

# %%
figureObject, axesObject = plt.subplots()

axesObject.pie(y,labels=x,autopct='%1.2f',startangle=90)
axesObject.axis('equal')
plt.show()

# %%
lists = sorted(temp2.items())
fig = plt.figure(figsize=(30,10))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Genres')
ax1.set_ylabel('Genres percentage')
ax1.set_title("Probability of each genre")
x, y = zip(*lists)
plt.scatter(x, y)
plt.show()
